# %%
for index, char_code in enumerate(range(0x0400, 0x04FF + 1)):
    cyrillic_letter = chr(char_code)
    print(index, cyrillic_letter)
# Out:
# 0 Ѐ
# 1 Ё
# 2 Ђ
# 3 Ѓ
# 4 Є
# 5 Ѕ
# 6 І
# 7 Ї
# 8 Ј
# 9 Љ
# 10 Њ
# 11 Ћ
# 12 Ќ
# 13 Ѝ
# 14 Ў
# 15 Џ
# 16 А
# 17 Б
# 18 В
# 19 Г
# 20 Д
# 21 Е
# 22 Ж
# 23 З
# 24 И
# 25 Й
# 26 К
# 27 Л
# 28 М
# 29 Н
# 30 О
# 31 П
# 32 Р
# 33 С
# 34 Т
# 35 У
# 36 Ф
# 37 Х
# 38 Ц
# 39 Ч
# 40 Ш
# 41 Щ
# 42 Ъ
# 43 Ы
# 44 Ь
# 45 Э
# 46 Ю
# 47 Я
# 48 а
# 49 б
# 50 в
# 51 г
# 52 д
# 53 е
# 54 ж
# 55 з
# 56 и
# 57 й
# 58 к
# 59 л
# 60 м
# 61 н
# 62 о
# 63 п
# 64 р
# 65 с
# 66 т
# 67 у
# 68 ф
# 69 х
# 70 ц
# 71 ч
# 72 ш
# 73 щ
# 74 ъ
# 75 ы
# 76 ь
# 77 э
# 78 ю
# 79 я
# 80 ѐ
# 81 ё
# 82 ђ
# 83 ѓ
# 84 є
# 85 ѕ
# 86 і
# 87 ї
# 88 ј
# 89 љ
# 90 њ
# 91 ћ
# 92 ќ
# 93 ѝ
# 94 ў
# 95 џ
# 96 Ѡ
# 97 ѡ
# 98 Ѣ
# 99 ѣ
# 100 Ѥ
# 101 ѥ
# 102 Ѧ
# 103 ѧ
# 104 Ѩ
# 105 ѩ
# 106 Ѫ
# 107 ѫ
# 108 Ѭ
# 109 ѭ
# 110 Ѯ
# 111 ѯ
# 112 Ѱ
# 113 ѱ
# 114 Ѳ
# 115 ѳ
# 116 Ѵ
# 117 ѵ
# 118 Ѷ
# 119 ѷ
# 120 Ѹ
# 121 ѹ
# 122 Ѻ
# 123 ѻ
# 124 Ѽ
# 125 ѽ
# 126 Ѿ
# 127 ѿ
# 128 Ҁ
# 129 ҁ
# 130 ҂
# 131 ҃
# 132 ҄
# 133 ҅
# 134 ҆
# 135 ҇
# 136 ҈
# 137 ҉
# ...
